# %% [markdown]
# # 1. 군집분석
# * 비지도학습
# * 여러 변수로 표현된 자료들 사이의 유사성을 측정하고 유사한 자료들끼리 몇 개의 군집 (Cluster) 으로 묶는다.
# * 그 군집들을 다변량 분석(상관분석， 회귀분석， 주성분분석 등)을 활용
# 하여 각군집에 대한 특징을 파악하는 기법이다.
# * 생물학에서는 종의 분류， 마케팅에서는 시장 세분화 금융에서는 산업 분석 등 다양하게 활용되고 있다.
# * 협업 필터링 (Collaborative Filtering) 같은 추천 서비스가 등장히는 기반을 제공

# %% [markdown]
# # 2. 거리측도 *** - 관측치의 유사도를 측정하기 위한 방법
# * 변수가 연속형인 경우
#  * 유클리디안 거리(Euclidean)
#  * 맨하튼 거리 (Manhattan)
#  * 민코프스키 거리
#  * 체비셰프 거리 (Chebychev)
#  * 표준화 거리 (Standardi zed)
#  * 마할라노비스거리
#
# * 변수가 범주형인 경우
#  * 단순 일치 계수
#  * 자카드 지수
#  * 자카드 거리
#  * 코사인 유사도
#  * 코사인 거리
#  * 순위 상관 계수

# %% [markdown]
# ## 1) 변수가 연속형인 경우 대표 거리 측도

# %% [markdown]
# ### (1) 유클리디안 거리(Euclidean)
# * 두 점 시어의 거리를 계산할 때 가장 널리 쓰이는 계산 방법
# * 두 점 사이의 가장 짧은 거리를 계산

# %% [markdown]
# ### (2) 맨하튼 거리 (Manhattan)
# * 두 점 사이를 가로지르지 않고 길을 따라 갔을 때의 거리
# * 시에서 최단거리를 움직이듯 변수들의 차이의 단순합으로 계산한 거리

# %% [markdown]
# ![유클리드_맨하튼.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (3) 민코프스키(Minkowski)거리
# * 유클리디안 거리와 맨하튼 거리를 한번에 표현한 거리로
# * m=1 일 때는 맨하튼 거리， m =2 일 때는 유클리디안 거리

# %% [markdown]
# ### (4) 체비셰프 거리 (Chebychev)
# * 변수 간 거리 차이 중 최대값을 데이터 간의 거리로 정의

# %% [markdown]
# ![군집분석_유클리드_맨하튼_체비셰프거리.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2) 변수가 범주형인 경우 거리 척도
# * 데이터가 범주형 변수인 경우에는 얼마나 많은 공통된 요소를 갖고 있는지로 판단

# %% [markdown]
# ### (1) 단순 일치 계수
# * 두 객체 i와 j 간의 상이성을 불일치 비율로 계산한다 p는 변수의 총 개수이며, m은 객체 i와j가 같은 상태인 변수의 수(일치한 수)를 의미

# %% [markdown]
# ![범주형변수거리계산01_단순일치계수.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (2) 자카드 지수, 자카드 거리 - 집합의 유사도 측정
# #### A. 자카드 지수
# * 두 집합 사이의 유사도를 측정하는 지표
# * 두 집합이 같으면 1, 완전히 다르면 0

# %% [markdown]
# #### B. 자카드 거리
# * 1 - 자카드 지수
# * 두 집합이 완전히 같으면 가장 가까운 거리 0
# * 두 집합이 완전히 다르면 먼 거리를 갖는 1

# %% [markdown]
# ![범주형변수거리계산01_자카드지수.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (3) 코사인 유사도, 코사인 거리 - 텍스트의 유사도 측정

# %% [markdown]
# #### A. 코사인 유사도
# * 문서(텍스트)의 유사도를 측정하기 위한 지표로서 크기가 아닌 방향성을 측정
# * 완전히 일치하면 1,  완전히 다른 방향이면 -1

# %% [markdown]
# #### B. 코사인 거리
# * 1 - 코사인 유사도
# * 방향 일치 = 가장 가까운 거리 0
# * 방향 불일치 = 가장 먼거리 1

# %% [markdown]
# ![범주형변수거리계산03_코사인유사도.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (4) 순위 상관 계수
# * 순서척도인 두 데이터 사이의 거리를 측정하기 위한 지표
# * 스피어만 상관계수 사용

# %% [markdown]
# # 3. 계층적 군집화
# * **병합적 방법 - 계층적 군집화(hierachical clustering)**는 여러개의 군집 중에서 가장 유사도가 높은 혹은 거리가 가까운 군집 두 개를 선택하여 하나로 합치면서 군집 개수를 줄여 가는 방법을 말한다.
# * N 개의 군집으로 시작하고, 가장 근접하고 유사한 두 개의 군집들을 1개의 군집으로 병합한다.
# * 가장 거리가 짧은 두 개의 군집들이 순차적으로 병합한다.

# %% [markdown]
# ## 1) 군집간의 거리 측정 방법

# %% [markdown]
# ### (1) 최단 연결법(single-link) - 단일연결법
# * 군집과 군집 혹은 데이터 간의 거리 중 최단거리 값을 거리로 산정한다.
# * 대부분 관측치가 멀리 떨어져 있어도 하나의 관측치만 다른 군집과 가까이 있으면 병합이 가능하다.

# %% [markdown]
# ### (2) 최장 연결법(complete-link) - 완전연결법
# * 군집과 군집 혹은 데이터 간의 거리 중 최장거리 값을 거리로 산정한다.
# * 내부 응집성에 중범을 둔 방법으로 둥근 형태의 군집이 형성된다.

# %% [markdown]
# ### (3) 평균 연결법(average-link)
# * 군집과 군집 혹은 데이터 간의 거리의 평균거리 값을 거리로 산정한다.
# * 생성된 군집과 기존 데이터들의 거리를 군집 내 평균 데이터로 계산하는 방법이다.
# * 계산량이 불필요하게 많아질 수 있으며, 단일 연결법과 완전 연결법보다 이상치에 덜 민감하다.

# %% [markdown]
# ### (4) Ward 연결법
# * 군집 내 편차들의 제곱합을 고려한 군집 내 거리를 기준으로 한다.
# * 생성된 군집과 기존의 데이터들의 거리를 군집 내 오차가 최소가 되는 데이터로 계산하는 방법.
# * 비슷한 크기의 군집끼리 병합하는 경향이 있으며 군집 내 분산을 최소로 하기 때문에 좀 더 조밀한 군집이 생성될 수 있다.

# %% [markdown]
# ![계층적군집_군집간거리측정방법.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 4. 비계층적 군집화
# * 계층적으로 군집을 형성하지 않고 구하고자 하는 군집의 수를 사전에 정의해 정해진 군집의 수만큼 형성하는 방법

# %% [markdown]
# ## 1) K-평균군집(K-means군집) ***
# * 군집의 수(K)를 사전에 정한 뒤 집단 내 동질성과 집단 간 이질성이 모두 높게 전체 데이터를 K개의 군집으로 분할
# * 군집의 수 K의 초깃값을 설정하고 각각의 k를 설명할 변수의 값을 임의로 설정된 K개의 데이터를 seed라 한다.

# %% [markdown]
# ### (1) k-means 군집의 방법***

# %% [markdown]
# ![k-means01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![k-means02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![k-means03.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![k-means04.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![k-means05.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### (2) K-means 군집의 특징 **

# %% [markdown]
# #### A. 장점
# * 분석 기법의 적용이 비교적 단순하고 빠르다.
# * 다양한 데이터에서 사용 가능하다.

# %% [markdown]
# #### B.단점
# * 초깃값 K개의 설정이 어럽다
# * 결과의 해석에 어려움이 있다
# * 데이터의 변수들이 연속형 변수여야 한다
# * 안정된 군집은 보장하나 최적의 보장은 없다.
# * 이상값에 민감하게 반응한다. -> 평균값 대신 중앙값 사용

# %% [markdown]
# ![k-means06.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 2) DBSCAN(Density Based Spatial Clustering of Applications with Noise)
# * 밀도 기반 군집화의 대표적인 알고리즘
# * 데이터의 분포가 기하학적으로 복잡한 데이터 세트에도 효과적인 군집화 가능

# %% [markdown]
# ### (1) DBSCAN의 가장 중요한 두 가지 파라미터
# * 입실론주변 영역(epsilon): 개별 데이터를 중심으로 입실론 반경을 가지는 원형의 영역
# * 최소 데이터 개수(min points): 개별 데이터의 입실론 주변 영역에 포함되는 타 데이터의 개수

# %% [markdown]
# ### (2) 입실론 주변 영역 내에 포함되는 최소 데이터 갯수를 충족하는지에 따른 데이터 포인터
# * 핵심 포인트(Core Point): 주변 영역내에 최소 데이터 개수 이상의 타 데이터를 가지고 있을 경우
# * 이웃 포인트(Neighbor Point): 주변 영역 내에 위치한 타 데이터
# * 경계 포인트(Border Point): 주변 영역 내에 최소 데이터 개수 이상의 이웃 포인트를 가지고 있지 않지만 핵심 포인트를 이웃포인트로 가지고 있는 데이터
# * 잡은 포인트(Noise Point): 최소 데이터 개수 이상의 이웃 포인트를 가지고 있지 않으며, 핵심 포인트도 이웃 포인트로 가지고 있지 않은 데이터

# %% [markdown]
# ### (3) P1 에서 P12까지 데이터에 대한 DBSCAN 군집화 적용의 사례

# %% [markdown]
# ![DBSCAN_01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### A. P1 데이터를 기준으로 입실론 반경 내에 포함된 데이터가 7개로 최소 데이터 5개 이상을 만족하므로 P1 데이터는 핵심 포인트(Core Point)

# %% [markdown]
# ![DBSCAN_02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### B. P2도 반경 내에 6개의 데이터를 가지고 있으므로 핵심포인트

# %% [markdown]
# ![DBSCAN_03.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### C. 핵심포인트 P1의 이웃 데이터 포인트 P2도 핵심 포인트일 경우 P1에서 P2로 연결해 직접 접근 가능

# %% [markdown]
# ![DBSCAN_04.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### D. 특정 핵심 포인트에서 직접 접근이 가능한 다른 핵심 포인트를 서로 연결하면서 군집화(단계적으로 군집 영역을 확장해 나가는 것이 DBSCAN)

# %% [markdown]
# ![DBSCAN_05.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### E. P3의 경우 반경 내에 포함되는 이웃 데이터가 P2, P4로 2개이므로 군집으로 구분할 수 있는 핵심포인트가 아님.
# #### 하지만 이웃 데이터 중에 핵심포인트인 P2가 있으므로 자신은 핵심포인트가 아니지만 이웃 데이터로 핵심 포인트를 가지고 있는 경계 포인트(Border Point)가 됨
# #### 경계 포인트는 군집의 외곽을 형성

# %% [markdown]
# ![DBSCAN_06.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### F. P5의 경우 반경 내에 최소 데이터를 가지고 있지도 않고, 핵심 포인트가 이웃으로 있지도 않아 잡음 포인트(Noise Point)가 된다.

# %% [markdown]
# ![DBSCAN_07.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 5. 혼합분포 군집

# %% [markdown]
# ## 1) 혼합 분포 군집 개요
# * 관측된 데이터들은 여러 개의 확률분포(흔히 정규분포)로부터 추출되었다는 가정하에 같은 확률분포에서 추출된 데이터들끼리 군집화히는 분석 기법
# * 데이터들이 몇 개의 획률분포로 구성되어 있는지， 각각의 확률분포의 모수(평균， 분산)와 그 확률분포가 전체 데이터에서 차지하는 비중(가중치)을 찾는 것이 혼합 분포 군집의 핵심이다. 이때 모수와 가중치를 추정하는 방법으로는 EM(기대값 최대화) 알고리즘을 시용한다.

# %% [markdown]
# ## 2) EM 알고리즘 **

# %% [markdown]
# * 기댓값 최대회{EM ， Expectation Maximization) 알고리즘은 획률모델의 최대가능도(Maximum Likelihood)를 갖는 모수와 함께 그 확률모댈의 가중치를 추정하고자 한다.
# * 각 데이터가 어느 분포에서 추출된 데이터인지 각 집단(잠재변수 z)으로부터 기댓값을 구할 수 있다. 이때 추정된 기댓값을 활용하여 로그-가능도 함수가 최대로 되게 하는 모수를 찾을 수 있다.
# * 알고리즘으로 두 가지 단계 (E -step, M -step)로 구성되어 있다.

# %% [markdown]
# ![혼합분포군집01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![혼합분포군집02.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![혼합분포군집03.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![혼합분포군집04.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![혼합분포군집05.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # 6. 자기조직화지도(SOM) - 딥러닝 기반 군집분석

# %% [markdown]
# ## 1) 자기조직화지도 개요
# * 코호넨 맵 이라고도 불리며 인공신경망 기반 차원축소와 군집화를 동시에 수행할 수 있는 알고리즘
# * 다차원 데이터를 축소해 저차원의 지도를 생성하고 이를 통해 데이터를 가시화하는 데 유용하다
# * 고차원 데 이터를 한눈에 파악하기 쉬운 저차원(2차원) 공간에 정렬하여 나타내는 시각화 방법 중 하나다

# %% [markdown]
# ## 2) 자기조직화지도 구성 **
# * 은닉층을 보유한 다층신경 망과 달리 은닉층이 없이 j 개 의 데이터를 입력받는 입 력층과 이를 n개의 노드(뉴런)로 표현하고자 하는 경쟁층으로 구성되어 있으며， 입력층의 모든 데이터는 경쟁층의 모든 노드와 완전연결 (fully connected) 되어 있다.
# * 각 학습 단계마다 임의의 프로토타입 벡터(경쟁층의 각각의 뉴런을 의미)와의 거리를 유클리디안 거리에 의해 계산하고 비교한다. 이때 입력층의 표본 벡터 에 가장 가까운 프로토타입 벡터를 BMU(Best-Matching Unit) 라 부른다. 최종적으로 경쟁층에 있는 노드들 중 가장 가까운 하나의 노드에만 도달하게 되는데 ， 그 노드를 승자 노드(winning node) 라 부른다.

# %% [markdown]
# ![SOM_01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## 3) 자기조직화지도 과정 ***
# * 1단계: 초기 학습률{ ao) 과 임의의 값의 가중치 행렬， 경쟁층의 노드 개수를 지정효봐.
# * 2단계: 입력 벡터(첫 번째 데이터)를 제시하고 가중치 행렬에 의하여 가장 가까운 노드에 나타낸다.
# * 3단계: 입력 벡터에 대한 승자 노드가 입력 벡터를 더 잘 나타내도록 학습률을 사용하여 해당 가중치를 재조정한다.
# * 4단계: 2단계로 돌아가서 반복하여 모든 입력 벡터를 승자노드에 나타낸다. 모든 입력 벡터가 승자노드에 표시되는 과정을 1회의 iteration( 반복)이라 한다.
# * 5단계: 일정 iteration( 반복) 수에 도달할 때까지 2번으로 돌아가 위 작업을 반복한다.(단, 반복하는 과정에서 입력 벡터에 대한 승자노드는 변경될 수 있다.

# %% [markdown]
# ## 4) 자기조직화지도 특성 **
# * 인공신경망의 일종이지만 다층신경망과 달리 은닉층을 보유하고 있지 않으며， 순전파 방식만 시용하여 알고리즘을 수행하는 속도가 매우 빠르다.

# %% [markdown]
# ### (1) 장점
# * 순전파 방식을 사용하여 속도가 매우 빠르다
# * 저차원의 지도로 형상화되어 시각적 이해가 쉽다
# * 패턴 발견 및 이미지 분석에서 성능이 우수하다.
# * 입력 데이터에 대한 속성을 그대로 보존한다

# %% [markdown]
# ### (2) 단점
# * 초기 학습률 및 초기 가중치에 많은 영향을 받는다
# * 경쟁층의 이상적인 노드의 개수를 결정하기 어렵다.

# %% [markdown]
# # 7. 군집 분석 모형의 평가

# %% [markdown]
# ![군집모형의평가_01.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![군집모형의평가_02.jpg](data:image/jpeg;base64,...)
